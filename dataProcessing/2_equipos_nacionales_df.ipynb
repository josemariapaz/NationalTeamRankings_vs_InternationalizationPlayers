# %%
## Se importan los paquetes necesarios para trabajar.

import pandas as pd
import numpy as np
import os

# %%
## Se carga el dataset 'equiposnac' creado en el paso anterior a partir del archivo 'equiposnac.csv'

equiposnac = pd.read_csv('equiposnac.csv') 
equiposnac = equiposnac.drop(['Unnamed: 0'],axis=1)

# %%
## Se identifica el pais de origen de todos los clubes del dataset equiposnac.

clubes_bolivia = ['Oriente','Bolivar','Blooming','San José','The Strongest','Guabira','Wilstermann','RSC','Union Central',
                 'Real Potosi','Univ. Iberoam.','Aurora','Universitario','La Paz FC','Callejas','Nacional Potosí',
                  'Sport Boys','Petrolero','Ciclón','Quebracho','Royal Pari','Destroyers','Always Ready']
clubes_colombia = ['Santa Fe','Cucuta','Independiente','Pasto','Tolima','América Cali','Junior','Atl. Nacional','Once Caldas',
                  'Millonarios','Dep. Cali','Barranquilla','Quindio','Bucaramanga','Cortuluá','Pereira','U Magdalena',
                  'Envigado','Centauros','Cartagena','Chico','La Equidad','Huila','Patriotas']
clubes_chile = ['Cobreloa','Temuco','Colo Colo',"O'Higgins",'Univ. de Chile','Huachipato','Uni. Catolica','Uni. Concepcion',
               'Union Española','Osorno','CD Everton','Coquimbo Unido','Palestino','D. Concepción','Regional Atacama',
               'Audax Italiano','La Serena','Morning','Puerto Montt','San Felipe','Nublense','Melipilla','Iquique',
                'Antofagasta','La Calera','San Marcos']
clubes_portugal = ['Boavista','Alverça','Naval','Benfica','Braga','FC Porto','Belenenses','Guimarães','União','Felgueiras',
                  'Rio Ave','Paços','Vitória S.','Maritimo','Arouca','Tondela','Olhanense','Salgueiros']
clubes_españa = ['Valladolid','Villarreal','Cádiz','Celta','Nastic','Real Madrid','R. Sociedad','Santander','Levante',
                'Atlético','Sevilla FC','Hércules','Saragosse','Depor','Granada CF','Elche','Sporting','Alavés','Barça',
                'Valencia CF','Girona','Espanyol','Huesca','Tenerife','Oviedo','Real Mallorca','UD Salamanque','Leganés',
                'Málaga','Murcia','Getafe','Almería','Betis','Recreativo','Osasuna','Numancia','Las Palmas','Albacete',
                 'Rayo','CP Mérida','Sanse','Castilla','Xerez','Sevilla Atlético','Eibar','Córdoba','Lleida','Pontevedra',
                'C. Murcia','Valence B','Ath. Bilbao','Peralada','Badajoz','Extremadura','Real Jaén','Barcelona']
clubes_argentina = ['San Lorenzo',"Newell's",'Lanus','Indep.','Gim. Jujuy','Argentinos','Chacarita','Rosario','Colon',
                    'Patronato','San Martin SJ','Boca Juniors','River Plate','Velez Sarsfield','Racing Club','Quilmes',
                   'Banfield','Estudiantes LP','Platense','Dep. Español','Gim. La Plata','Huracán','Tucuman','Godoy Cruz',
                   'Tigre','All Boys','Talleres','Defensa','Ferro','CAHCR','Union','Los Andes','Olimpo','Mandiyú']
clubes_mexico = ['Cruz Azul','San Luis','Tapachula','UNAM','Estudiantes','Correcaminos','Atlas','Puebla','Veracruz',
                 'Atlante','Pachuca','Irapuato','Necaxa','Zacatepec','Morelia','Sinaloa','Monterrey','Indios',
                'Santos Laguna','Chiapas','Tijuana','León','Tigres UANL','Toluca','Celaya','Leones Negros','América Mexico',
                 'Queretaro','Lobos BUAP','Neza','Saltillo','Juárez']
clubes_eu = ['D.C. United','Tampa Bay','New England','FC Dallas','Red Bulls','Cosmos','Richmond','Miami','Seattle',
            'Portland','Philadelphia','Atlanta Utd','LA Galaxy','Chivas','Salt Lake','Minnesota','LAFC','Orlando','Chicago',
            'Colorado','NYCFC','San Jose','Kansas City','Houston','Columbus']
clubes_japon = ['Yokohama FM','Urawa','Cerezo','Fukuoka','Gamba','Shimizu','Kashima','Yokohama F','Iwata']
clubes_paraguay = ['Cerro P','Libertad','Olimpia','Guarani','Cerro Cora','Luque','Sol','CA Colegiales','2 de Mayo',
                   'Silvio P','12 Oct.','Universal','Recoleta','Tacuary','Colombia','3 Feb.','Gen. Caballero','Rubio Ñu',
                  'Carapeguá','General Diaz','Capiatá']
clubes_ecuador = ['Barcelona G','Portoviejo','LDU Quito','Emelec','El Nacional','SD Quito','Aucas','Cuenca','Espoli',
                  'Olmedo','Delfin SC','Rocafuerte','Azogues','Imbabura SC','Reading','Macara','Guayaquil City','Manta',
                  'UCE','Indep JT','Grecia','LDU Loja','America']
clubes_uruguay = ['Nacional','Juventud','Aris','Defensor SC','Bella Vista','Peñarol','Wanderers','Cerro','Danubio',
                  'Progreso','Fénix','Central Español','Plaza Colonia','Miramar','Maldonado','IASA']
clubes_qatar = ['Al Wakrah','Al Arabi','Al Sadd','Al Gharafa']
clubes_venezuela = ['Caracas','Minervén','Mineros','Trujillanos','Tachira','Zulia','Petare','ULA','Nacional Tachira',
                   'Inter Lara','Zulianos','Union Lara','Monagas','UA Maracaibo','Carabobo','Zamora','Anzoategui',
                    'Llaneros','Aragua','Lara','Estrella Roja','La Guaira','Yaracuyanos','Portuguesa','Atl. Venezuela']
clubes_grecia =['Ionikos','Panetolikos','PAOK','Olympiakos','Pana','Panionios','Levadiakos','AEK Atenas']
clubes_peru = ['Alianza Lima','José Galvez','Sp. Cristal','Melgar','CD Pesquero','Municipal','Juan Aurich','Cienciano',
              'AA Sullana','Unión Minas Volcan','Deportivo Wanka','Bolognesi','U. San Martin','IDUNSA','UCV',
               'Total Chalaco','Huancayo','U. Comercio','Real Garcilaso','UTC','Ayacucho','Cantolao']
clubes_rumania = ['Cluj','Petrolul','FCSB','Din. Bucarest','Poli Iasi']
clubes_brasil =['Corinthians','Cruzeiro','Ipatinga','Recife','Santo André','Bahia','Grêmio','Botafogo','Ponte Preta',
               'Palmeiras','SPFC','Santos','Fluminense','Internacional','Atlético PR','Flamengo','Atlético MG','Vasco',
                'Figueirense','Guarani SP','Vitória','São Caetano','Juventus SP','Coritiba']
clubes_eslovenia = ['Nafta Lendava']
clubes_turquia = ['Bursaspor','Giresunspor','Sivasspor','Mersin','Galatasaray','Besiktas','Rizespor','Trabzonspor',
                  'Fenerbahçe','Yeni Malatya','Konyaspor','Alanyaspor','Kasimpasa','Kayserispor']
clubes_ucrania = ['Shakhtar','Goverla','Metalist','Metallurg D.','Chornomorets','Dynamo Kyiv','Dnipro']
clubes_israel = ['Kiryat Shmona','Mac. Netanya',"Ra'anana",'Mac. Haïfa','Beitar']
clubes_chipre = ['Anorthosis','Omonia','AEK','Alki','Anagennisi','APOEL']
clubes_inglaterra = ['Arsenal','Newcastle','Middlesbrough','Aston Villa','Portsmouth','Southampton','Wigan','West Ham',
                    'Man United','Chelsea','Tottenham','Brighton','Everton','Bournemouth','Liverpool','Man City',
                    'Sunderland','Blackburn','Watford','Birmingham','Charlton','WBA','Hull City','Man U','Nottingham','QPR',
                    'Swindon Town','Fulham','Leeds']
clubes_iran = ['Esteghlal T.']
clubes_tailandia = ['MTU','Pathum United','Buriram']
clubes_suecia = ['IFK Göteborg','AIK Solna','Malmö FF']
clubes_costarica = ['CD Saprissa']
clubes_italia = ['AC Milán','Parma','Bari','Reggio','Inter','Napoli','Udinese','Chievo','Siena','Pescara','Lecce',
                 'Cagliari','Fiorentina','Atalanta','AS Roma','Sampdoria','Juventus','Foggia','Lazio','Bologna','Palermo',
                 'Genoa','Catania','Torino','Vicenza','Venezia','Perugia','Como','Treviso','Reggina','Hellas Verona',
                 'Sassuolo','Salernitana','ACR Messina','Empoli','Ternana','Livorno','Brescia','Ancona','Padua','Grosseto',
                'Crotone']
clubes_china = ['Changchun','Wuhan Zall','Shijiazhuang','Sh. Shenhua','Hebei CF','Beijing Guoan','Guangzhou R&F','Shandong',
               'Guangzhou']
clubes_kuwait = ['Kazma']
clubes_alemania = ['Bayern','Bielefeld','Mainz','FC Köln','Hertha','Dortmund','Werder','HSV','Bayer','Wolfsburgo',
                   "M'gladbach",'FC Nürnberg','Stuttgart','Düsseldorf','Schalke 04','RB Leipzig','St. Pauli','E Francfort',
                  'Hoffenheim','Hannover 96','Waldhof M','Duisburgo','Augsburg','Ingolstadt']
clubes_francia = ['Metz','TFC','Nantes','Paris S-G','ASSE','RCS','Bordeaux','Niza','VA','Monaco','Rennes','Lyon',
                  'Marseille','MHSC','Auxerre','Lille','ACA','Le Mans']
clubes_arabiasaudita = ['Al Shabab','Al Ittihad','Al Hilal','Al Ahli','Al Wehda','Al Nassr']
clubes_rusia = ['Krylia Sovetov','Zenit','Spartak','Rubin Kazan','Dinamo Moscow','Lokomotiv M','Rostov','Krasnodar',
                'Saturn','CSKA','Mordovia','Akhmat','Anzhi']
clubes_belgica = ['FC Bruges','Standard','RC Genk','Anderlecht','La Gantoise','Lokeren','Westerlo','Charleroi',
                  'Saint-Trond','Eupen']
clubes_paisesbajos = ['PSV','Ajax','Feyenoord','AZ','Vitesse','Willem II','FC Groningen','FC Twente','RBC Roosendaal','NEC',
                     'Heerenveen']
clubes_bulgaria = ['Ludogorets','Litex','Cherno More']
clubes_suiza = ['FC Basel','Lugano','Grasshops','FC Lucerna','Kriens','Young Boys','Aarau','FC Thun']
clubes_escocia = ['Rangers','Hibernian','Hearts','Celtic','Dundee FC']
clubes_polonia = ['Legia','Lech Poznan']
clubes_emiratosarabes = ['Al Wasl','Al Jazira','Al Ain','Shabab Al Ahli','Baniyas','Al Wadha']
clubes_serbia = ['ER Belgrado']
clubes_canada = ['Toronto FC','Vancouver']
clubes_gales = ['Swansea','Cardiff']
clubes_hungria = ['Ferencváros']
clubes_austria = ['Sturm Graz','Grödig','Salzburg']
clubes_dinamarca = ['Aalborg','Bröndby','Copenhague']
clubes_croacia = ['Din. Zagreb']
clubes_noruega = ['Odd','Vaalerenga','Stabaek']
clubes_sudafrica = ['Sundowns','Kaizer Chiefs']
clubes_marruecos = ['Raja']
clubes_egipto = ['Wadi Degla']
clubes_coreadelsur = ['UHFC']
clubes_indonesia = ['Persija']
clubes_jubilado = ['Jubilado']
clubes_libre = ['libre']
clubes_ignorado = ['ignorado']

# %%
## El valor 'América' del campo 'club' puede referirse al América de México o al América de Cali.
## Se introduce manualmente el campo club en esos casos.

equiposnac.loc[(equiposnac['año']==1994)&(equiposnac['club']=='América'),'club']='América Cali'
equiposnac.loc[(equiposnac['año']==1995)&(equiposnac['club']=='América'),'club']='América Cali'
equiposnac.loc[(equiposnac['año']==1995)&(equiposnac['jugador']=='John Harold Lozano'),'club']='América Mexico'
equiposnac.loc[(equiposnac['año']==1995)&(equiposnac['jugador']=='Javier Margas'),'club']='América Mexico'
equiposnac.loc[(equiposnac['año']==1996)&(equiposnac['club']=='América'),'club']='América Cali'
equiposnac.loc[(equiposnac['año']==1996)&(equiposnac['jugador']=='Javier Margas'),'club']='América Mexico'
equiposnac.loc[(equiposnac['año']==1997)&(equiposnac['club']=='América'),'club']='América Cali'
equiposnac.loc[(equiposnac['año']==1998)&(equiposnac['club']=='América'),'club']='América Cali'
equiposnac.loc[(equiposnac['año']==1998)&(equiposnac['jugador']=='Rodrigo Valenzuela'),'club']='América Mexico'
equiposnac.loc[(equiposnac['año']==1999)&(equiposnac['club']=='América'),'club']='América Cali'
equiposnac.loc[(equiposnac['año']==2000)&(equiposnac['club']=='América'),'club']='América Cali'
equiposnac.loc[(equiposnac['año']==2000)&(equiposnac['jugador']=='Fabian Estay'),'club']='América Mexico'
equiposnac.loc[(equiposnac['año']==2001)&(equiposnac['club']=='América'),'club']='América Cali'
equiposnac.loc[(equiposnac['año']==2001)&(equiposnac['jugador']=='Frankie Oviedo'),'club']='América Mexico'
equiposnac.loc[(equiposnac['año']==2001)&(equiposnac['equiponac']=='Chile')&(equiposnac['club']=='América Cali'),'club']='América Mexico'
equiposnac.loc[(equiposnac['año']==2002)&(equiposnac['club']=='América'),'club']='América Cali'
equiposnac.loc[(equiposnac['año']==2003)&(equiposnac['club']=='América'),'club']='América Cali'
equiposnac.loc[(equiposnac['año']==2003)&(equiposnac['jugador']=='Frankie Oviedo'),'club']='América Mexico'
equiposnac.loc[(equiposnac['año']==2003)&(equiposnac['equiponac']=='Chile')&(equiposnac['club']=='América Cali'),'club']='América Mexico'
equiposnac.loc[(equiposnac['año']==2004)&(equiposnac['club']=='América'),'club']='América Cali'
equiposnac.loc[(equiposnac['año']==2004)&(equiposnac['jugador']=='Frankie Oviedo'),'club']='América Mexico'
equiposnac.loc[(equiposnac['año']==2004)&(equiposnac['equiponac']=='Chile')&(equiposnac['club']=='América Cali'),'club']='América Mexico'
equiposnac.loc[(equiposnac['año']==2005)&(equiposnac['club']=='América'),'club']='América Cali'
equiposnac.loc[(equiposnac['año']==2005)&(equiposnac['equiponac']=='Chile')&(equiposnac['club']=='América Cali'),'club']='América Mexico'
equiposnac.loc[(equiposnac['año']==2006)&(equiposnac['club']=='América'),'club']='América Cali'
equiposnac.loc[(equiposnac['año']==2006)&(equiposnac['equiponac']=='Chile')&(equiposnac['club']=='América Cali'),'club']='América Mexico'
equiposnac.loc[(equiposnac['año']==2007)&(equiposnac['club']=='América'),'club']='América Mexico'
equiposnac.loc[(equiposnac['año']==2007)&(equiposnac['equiponac']=='Colombia')&(equiposnac['club']=='América Mexico'),'club']='América Cali'
equiposnac.loc[(equiposnac['año']==2008)&(equiposnac['club']=='América'),'club']='América Cali'
equiposnac.loc[(equiposnac['año']==2008)&(equiposnac['equiponac']=='Paraguay')&(equiposnac['club']=='América Cali'),'club']='América Mexico'
equiposnac.loc[(equiposnac['año']==2009)&(equiposnac['club']=='América'),'club']='América Mexico'
equiposnac.loc[(equiposnac['año']==2009)&(equiposnac['equiponac']=='Colombia')&(equiposnac['club']=='América Mexico'),'club']='América Cali'
equiposnac.loc[(equiposnac['año']==2010)&(equiposnac['club']=='América'),'club']='América Mexico'
equiposnac.loc[(equiposnac['año']==2011)&(equiposnac['club']=='América'),'club']='América Mexico'
equiposnac.loc[(equiposnac['año']==2012)&(equiposnac['club']=='América'),'club']='América Mexico'
equiposnac.loc[(equiposnac['año']==2013)&(equiposnac['club']=='América'),'club']='América Mexico'
equiposnac.loc[(equiposnac['año']==2014)&(equiposnac['club']=='América'),'club']='América Mexico'
equiposnac.loc[(equiposnac['año']==2015)&(equiposnac['club']=='América'),'club']='América Mexico'
equiposnac.loc[(equiposnac['año']==2016)&(equiposnac['club']=='América'),'club']='América Mexico'
equiposnac.loc[(equiposnac['año']==2017)&(equiposnac['club']=='América'),'club']='América Mexico'
equiposnac.loc[(equiposnac['año']==2018)&(equiposnac['club']=='América'),'club']='América Mexico'
equiposnac.loc[(equiposnac['año']==2018)&(equiposnac['equiponac']=='Venezuela')&(equiposnac['club']=='América Mexico'),'club']='América Cali'
equiposnac.loc[(equiposnac['año']==2019)&(equiposnac['club']=='América'),'club']='América Mexico'

# %%
## Se crea el campo 'pais_club' en el que se etiqueta el pais de origen del club al que pertenece el jugador.

equiposnac.loc[equiposnac['club'].isin(clubes_bolivia), 'pais_club'] = 'Bolivia'
equiposnac.loc[equiposnac['club'].isin(clubes_colombia), 'pais_club'] = 'Colombia'
equiposnac.loc[equiposnac['club'].isin(clubes_chile), 'pais_club'] = 'Chile'
equiposnac.loc[equiposnac['club'].isin(clubes_españa), 'pais_club'] = 'España'
equiposnac.loc[equiposnac['club'].isin(clubes_portugal), 'pais_club'] = 'Portugal'
equiposnac.loc[equiposnac['club'].isin(clubes_argentina), 'pais_club'] = 'Argentina'
equiposnac.loc[equiposnac['club'].isin(clubes_mexico), 'pais_club'] = 'Mexico'
equiposnac.loc[equiposnac['club'].isin(clubes_eu), 'pais_club'] = 'Estados Unidos'
equiposnac.loc[equiposnac['club'].isin(clubes_japon), 'pais_club'] = 'Japón'
equiposnac.loc[equiposnac['club'].isin(clubes_paraguay), 'pais_club'] = 'Paraguay'
equiposnac.loc[equiposnac['club'].isin(clubes_ecuador), 'pais_club'] = 'Ecuador'
equiposnac.loc[equiposnac['club'].isin(clubes_uruguay), 'pais_club'] = 'Uruguay'
equiposnac.loc[equiposnac['club'].isin(clubes_qatar), 'pais_club'] = 'Qatar'
equiposnac.loc[equiposnac['club'].isin(clubes_venezuela), 'pais_club'] = 'Venezuela'
equiposnac.loc[equiposnac['club'].isin(clubes_grecia), 'pais_club'] = 'Grecia'
equiposnac.loc[equiposnac['club'].isin(clubes_peru), 'pais_club'] = 'Peru'
equiposnac.loc[equiposnac['club'].isin(clubes_rumania), 'pais_club'] = 'Rumania' 
equiposnac.loc[equiposnac['club'].isin(clubes_brasil), 'pais_club'] = 'Brasil'
equiposnac.loc[equiposnac['club'].isin(clubes_eslovenia), 'pais_club'] = 'Eslovenia'
equiposnac.loc[equiposnac['club'].isin(clubes_turquia), 'pais_club'] = 'Turquia'
equiposnac.loc[equiposnac['club'].isin(clubes_ucrania), 'pais_club'] = 'Ucrania'
equiposnac.loc[equiposnac['club'].isin(clubes_israel), 'pais_club'] = 'Israel'
equiposnac.loc[equiposnac['club'].isin(clubes_chipre), 'pais_club'] = 'Chipre'
equiposnac.loc[equiposnac['club'].isin(clubes_inglaterra), 'pais_club'] = 'Inglaterra'
equiposnac.loc[equiposnac['club'].isin(clubes_iran), 'pais_club'] = 'Iran'
equiposnac.loc[equiposnac['club'].isin(clubes_tailandia), 'pais_club'] = 'Tailandia'
equiposnac.loc[equiposnac['club'].isin(clubes_suecia), 'pais_club'] = 'Suecia'
equiposnac.loc[equiposnac['club'].isin(clubes_costarica), 'pais_club'] = 'Costa Rica'
equiposnac.loc[equiposnac['club'].isin(clubes_italia), 'pais_club'] = 'Italia'
equiposnac.loc[equiposnac['club'].isin(clubes_china), 'pais_club'] = 'China'
equiposnac.loc[equiposnac['club'].isin(clubes_kuwait), 'pais_club'] = 'Kuwait'
equiposnac.loc[equiposnac['club'].isin(clubes_alemania), 'pais_club'] = 'Alemania'
equiposnac.loc[equiposnac['club'].isin(clubes_francia), 'pais_club'] = 'Francia'
equiposnac.loc[equiposnac['club'].isin(clubes_arabiasaudita), 'pais_club'] = 'Arabia Saudita'
equiposnac.loc[equiposnac['club'].isin(clubes_rusia), 'pais_club'] = 'Rusia'
equiposnac.loc[equiposnac['club'].isin(clubes_belgica), 'pais_club'] = 'Belgica'
equiposnac.loc[equiposnac['club'].isin(clubes_paisesbajos), 'pais_club'] = 'Paises Bajos'
equiposnac.loc[equiposnac['club'].isin(clubes_bulgaria), 'pais_club'] = 'Bulgaria'
equiposnac.loc[equiposnac['club'].isin(clubes_suiza), 'pais_club'] = 'Suiza'
equiposnac.loc[equiposnac['club'].isin(clubes_escocia), 'pais_club'] = 'Escocia'
equiposnac.loc[equiposnac['club'].isin(clubes_polonia), 'pais_club'] = 'Polonia'
equiposnac.loc[equiposnac['club'].isin(clubes_emiratosarabes), 'pais_club'] = 'Emiratos Arabes'
equiposnac.loc[equiposnac['club'].isin(clubes_serbia), 'pais_club'] = 'Serbia'
equiposnac.loc[equiposnac['club'].isin(clubes_canada), 'pais_club'] = 'Canada'
equiposnac.loc[equiposnac['club'].isin(clubes_gales), 'pais_club'] = 'Gales'
equiposnac.loc[equiposnac['club'].isin(clubes_hungria), 'pais_club'] = 'Hungria'
equiposnac.loc[equiposnac['club'].isin(clubes_austria), 'pais_club'] = 'Austria'
equiposnac.loc[equiposnac['club'].isin(clubes_dinamarca), 'pais_club'] = 'Dinamarca'
equiposnac.loc[equiposnac['club'].isin(clubes_croacia), 'pais_club'] = 'Croacia'
equiposnac.loc[equiposnac['club'].isin(clubes_noruega), 'pais_club'] = 'Noruega'
equiposnac.loc[equiposnac['club'].isin(clubes_sudafrica), 'pais_club'] = 'Sudafrica'
equiposnac.loc[equiposnac['club'].isin(clubes_marruecos), 'pais_club'] = 'Marruecos'
equiposnac.loc[equiposnac['club'].isin(clubes_egipto), 'pais_club'] = 'Egipto'
equiposnac.loc[equiposnac['club'].isin(clubes_coreadelsur), 'pais_club'] = 'Corea del Sur'
equiposnac.loc[equiposnac['club'].isin(clubes_indonesia), 'pais_club'] = 'Indonesia'
equiposnac.loc[equiposnac['club'].isin(clubes_jubilado), 'pais_club'] = 'Jubilado'
equiposnac.loc[equiposnac['club'].isin(clubes_libre), 'pais_club'] = 'Libre'
equiposnac.loc[equiposnac['club'].isin(clubes_ignorado), 'pais_club'] = 'Ignorado'

# %%
path = os.getcwd()

# %%
## Se graba el archivo equiposnacs.csv con el dataset.
equiposnac.to_csv(path+'\\equiposnac2.csv')
